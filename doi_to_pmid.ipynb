# %%
import pandas as pd
import urllib.request
import json

# %%
base_url = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0"
result_format = "json"

df = pd.read_csv("https://raw.githubusercontent.com/foerstner-lab/Publication_list/master/Publications.tsv", sep="\s")
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
pmid_list = []
for doi in df.DOI:
    full_url = f"{base_url}?ids={doi}&format={result_format}"
    request_data_of_doi = urllib.request.urlopen(full_url).read()
    result_of_doi_as_dict = doi_data = json.loads(request_data_of_doi)
    try:
        for result_of_pmid in result_of_doi_as_dict["records"]:
            pmid_list.append((result_of_pmid["pmid"]))
    except:
        pmid_list.append("None")
df.update({"PMID": pmid_list})

# %%
df
# Out:
#                                 DOI      PMID Wikidata_item_identifier  \
# 0          10.3389/fmicb.2019.01181  31191497                     None
# 1          10.3389/fnins.2019.00460  31133792                     None
# 2   10.1097/j.pain.0000000000001623      None                     None
# 3      10.1371/journal.pone.0215986  31039177                     None
# 4               10.1128/JB.00730-18  30885931                     None
# 5                 10.1111/mmi.14238      None                     None
# 6      10.1371/journal.ppat.1007618  30870530                     None
# 7         10.1038/s41586-018-0619-8      None                     None
# 8     10.1080/15476286.2018.1514234  30153081                     None
# 9        10.1093/gigascience/giy096  30169674                      NaN
# 10               10.1093/nar/gky765  30165530                     None
# 11           10.26508/lsa.201800080  30456366                     None
# 12          10.1111/1462-2920.14360      None                     None
# 13         10.3389/fmicb.2018.01473  30050506                     None
# 14         10.3389/fmicb.2018.00929  29896160                     None
# 15             10.1128/AAC.01510-17  29133557                     None
# 16         10.3389/fmicb.2017.01941  29067007                     None
# 17        10.1186/s12974-017-0924-4  28738885                     None
# 18          10.15252/embj.201695323  28701485                     None
# 19    10.1080/15476286.2017.1341020  28665778                     None
# 20              10.1128/JB.00249-17  28507242                     None
# 21    10.1080/15476286.2017.1306170  28296572                     None
# 22               10.1093/nar/gkx137  28334975                     None
# 23            10.1128/mBio.02041-16  28196958                     None
# 24     10.1016/j.molcel.2016.11.002  28061332                     None
# 25         10.3389/fmicb.2016.01858  27917168                     None
# 26                10.1038/srep35307  27748404                     None
# 27          10.1073/pnas.1609981113  27671629                     None
# 28        10.1186/s12864-016-2920-y  27519343                     None
# 29            10.1128/mBio.00813-16  27486191                     None
# ..                              ...       ...                      ...
# 38          10.1073/pnas.1500203112  25646441                     None
# 39     10.1371/journal.pcbi.1003905  25633715                     None
# 40    10.12688/f1000research.5686.2  25653839                     None
# 41          10.1074/jbc.M114.612663  25352599                     None
# 42     10.1371/journal.pone.0110427  25330313                     None
# 43              10.1128/JB.02096-14  25266388                     None
# 44         10.1186/1471-2164-15-794  25220182                     None
# 45       10.1016/j.cell.2014.06.046  25171407                     None
# 46               10.1038/ncomms5718      None                     None
# 47         10.1186/1471-2164-15-684  25127548                     None
# 48    10.1093/bioinformatics/btu533      None                Q22951230
# 49               10.1093/nar/gku714  25104019                     None
# 50             10.1128/AEM.01835-14  25002423                     None
# 51                10.4161/rna.29440  24922065                     None
# 52               10.1093/nar/gkt634  23877245                     None
# 53     10.1371/journal.pgen.1003576  23818867                     None
# 54     10.1371/journal.pgen.1003495  23696746                     None
# 55              10.1128/JB.00746-12  22923593                     None
# 56           10.1105/tpc.111.089441  22267485                     None
# 57              10.1038/nature09944  21508958                     None
# 58            10.3233/ISU-2011-0621      None                     None
# 59     10.1371/journal.pone.0003515  18953415                     None
# 60     10.1371/journal.pone.0003976  19096720                     None
# 61     10.1371/journal.pone.0003515  18953415                     None
# 62     10.1371/journal.pone.0002607  18612393                     None
# 63        10.1016/j.mib.2007.09.001      None                     None
# 64         10.1038/sj.emboj.7601699  17464285                     None
# 65       10.1016/j.ijmm.2005.11.011      None                     None
# 66           10.1098/rstb.2005.1809  16524840                     None
# 67         10.1038/sj.embor.7400538  16200051                     None
#
#          PMCID  Preprint_DOI
# 0         None           NaN
# 1         None           NaN
# 2         None           NaN
# 3         None           NaN
# 4         None           NaN
# 5         None           NaN
# 6         None           NaN
# 7         None           NaN
# 8         None           NaN
# 9   PMC6123526           NaN
# 10        None           NaN
# 11        None           NaN
# 12        None           NaN
# 13        None           NaN
# 14        None           NaN
# 15        None           NaN
# 16        None           NaN
# 17        None           NaN
# 18        None           NaN
# 19        None           NaN
# 20        None           NaN
# 21        None           NaN
# 22        None           NaN
# 23        None           NaN
# 24        None           NaN
# 25        None           NaN
# 26        None           NaN
# 27        None           NaN
# 28        None           NaN
# 29        None           NaN
# ..         ...           ...
# 38        None           NaN
# 39        None           NaN
# 40        None           NaN
# 41        None           NaN
# 42        None           NaN
# 43        None           NaN
# 44        None           NaN
# 45        None           NaN
# 46        None           NaN
# 47        None           NaN
# 48        None           NaN
# 49        None           NaN
# 50        None           NaN
# 51        None           NaN
# 52        None           NaN
# 53        None           NaN
# 54        None           NaN
# 55        None           NaN
# 56        None           NaN
# 57        None           NaN
# 58        None           NaN
# 59        None           NaN
# 60        None           NaN
# 61        None           NaN
# 62        None           NaN
# 63        None           NaN
# 64        None           NaN
# 65        None           NaN
# 66        None           NaN
# 67        None           NaN
#
# [68 rows x 5 columns]
